# %%
def f(x=0, y=5, z=15):
  print("x is " + str(x))
  print("y is " + str(y))
  print("z is " + str(z))

# %%
f(y=25, 5, 10)
# Out:
#   File "<ipython-input-70-0ebb6bac2d5c>", line 1
#     f(y=25, 5, 10)
#            ^
# SyntaxError: positional argument follows keyword argument
