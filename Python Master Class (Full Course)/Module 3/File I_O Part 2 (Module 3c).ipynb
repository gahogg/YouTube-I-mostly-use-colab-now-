# %%
with open("hey.txt", 'w') as f:
  x = ['hey1', 'hey2']
  for a in x:
    f.write(a + '\n')

# %%
with open("hey.txt", 'a') as f:
  x = ['hey3', 'hey4']
  for a in x:
    f.write(a + '\n')

# %%
a = input('hey\n')
# Out:
# hey
# yup
