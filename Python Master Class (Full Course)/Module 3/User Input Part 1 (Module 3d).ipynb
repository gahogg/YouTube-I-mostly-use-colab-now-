# %%
s = input('Give me an integer\n')
# Out:
# Give me an integer
# hi

# %%
int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-2c4720ab420a> in <module>()
# ----> 1 int(s)
#
# ValueError: invalid literal for int() with base 10: 'hi'
