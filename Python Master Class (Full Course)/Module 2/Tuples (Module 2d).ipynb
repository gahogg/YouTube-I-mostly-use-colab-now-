# %%
[1, 2, 3, 3]
# Out:
# [1, 2, 3, 3]

# %%
(1, 2, 3, 3)
# Out:
# (1, 2, 3, 3)

# %%
lst = [1, 2, 3, 3]

# %%
lst[0] = 5

# %%
lst
# Out:
# [5, 2, 3, 3]

# %%
t = (1, 2, 3, 3)

# %%
t = t + (4,)
t
# Out:
# (1, 2, 3, 3, 4)
