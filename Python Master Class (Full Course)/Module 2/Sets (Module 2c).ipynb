# %%
{1, 2, 3, 3}
# Out:
# {1, 2, 3}

# %%
set([1, 2, 3, 3])
# Out:
# {1, 2, 3}

# %%
s1 = {1, 2, 3}
s2 = {4, 5, 6}
s1.intersection(s2)
# Out:
# set()

# %%
1 in [1, 2, 3]
# Out:
# True

# %%
s = set()
for elem in [1, 2, 3, 3]:
  s.add(elem)

# %%
s
# Out:
# {1, 2, 3}
