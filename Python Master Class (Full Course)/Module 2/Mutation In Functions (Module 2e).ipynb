# %%
def f(lst):
  x = lst
  x[0] = 5

# %%
t = (1, 2, 3)
f(t)
t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-394df180daf0> in <module>()
#       1 t = (1, 2, 3)
# ----> 2 f(t)
#       3 t
#
# <ipython-input-63-fc9775c0e1ac> in f(lst)
#       1 def f(lst):
#       2   x = lst
# ----> 3   x[0] = 5
#
# TypeError: 'tuple' object does not support item assignment
