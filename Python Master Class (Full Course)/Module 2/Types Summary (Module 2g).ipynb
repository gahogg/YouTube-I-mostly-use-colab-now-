# %%
i = 7
f = 5.2
s = "Hi"
t = (1, 2, 3)

lst = [1, 2, 3]
sett = {1, 4, 2, 3}
d = {'a':1, 'd':4, 'b':2, 'c':3}

# %%
lst[0]
t[0]
s[0]

for elem in lst
for elem in sett
for elem in d
for elem in t
# Out:
# 'H'

# %%
for elem in t:
  print(elem)
# Out:
# 1
# 2
# 3
