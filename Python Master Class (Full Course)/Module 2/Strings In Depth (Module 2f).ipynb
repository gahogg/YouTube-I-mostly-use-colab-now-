# %%
"Hi my name is Greg"
# Out:
# 'Hi my name is Greg'

# %%
sentence = "My name is "

# %%
sentence = sentence + "Greg"

# %%
t = (1, 2, 3)

# %%
sentence = sentence + "Hello"

# %%
sentence
# Out:
# 'My name is GregHello'

# %%
sentence = "H" + sentence[1:]
sentence
# Out:
# 'Hy name is GregHello'

# %%
lst = [1, 2, 3]
lst[1:]
# Out:
# [2, 3]

# %%
for character in sentence:
  print(character)
# Out:
# H
# y
#
# n
# a
# m
# e
#
# i
# s
#
# G
# r
# e
# g
# H
# e
# l
# l
# o
