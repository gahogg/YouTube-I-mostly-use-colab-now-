# %%
names =  ['Greg', 'John', 'Jeff']
colors = ['Red', 'Orange', 'Blue']
indices =[0,        1,        2]

# %%
names_and_colors = ['Greg', 'Red', 'John', 'Orange', 'Jeff', 'Blue']

# %%
names_and_colors_dict = {'Greg':'Red', 'John':'Orange', 'Jeff':'Blue'}

# %%
d['Greg']
# Out:
# 'Red'

# %%
names_and_colors_dict['John']
# Out:
# 'Orange'

# %%
names_and_colors_dict['John'] = 'Pink'

# %%
names_and_colors_dict
# Out:
# {'Greg': 'Red', 'Jeff': 'Blue', 'John': 'Pink'}

# %%
names_and_colors_dict['Sarah'] = 'Green'

# %%
names_and_colors_dict
# Out:
# {'Greg': 'Red', 'Jeff': 'Blue', 'John': 'Pink', 'Sarah': 'Green'}

# %%
for name in names_and_colors_dict:
  print(name + "'s favorite color is " + names_and_colors_dict[name])
# Out:
# Greg's favorite color is Red
# John's favorite color is Pink
# Jeff's favorite color is Blue
# Sarah's favorite color is Green
