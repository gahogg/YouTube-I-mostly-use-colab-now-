# %%
lst2 = [2, 4, 5, 7, 8, 9]

# %%
even_vals = []

for val in lst2:
  if (val % 2) == 0:
    even_vals += [val]

# %%
even_vals
# Out:
# [2, 4, 8]

# %%
even_vals.pop()
# Out:
# 2

# %%
even_vals = [1]

# %%
if even_vals:
  print('There is something in even_vals')
# Out:
# There is something in even_vals
