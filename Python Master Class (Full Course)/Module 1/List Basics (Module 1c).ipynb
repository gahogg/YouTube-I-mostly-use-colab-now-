# %%
[1, "Hey", True, False][4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-0cbe727e09ef> in <module>()
# ----> 1 [1, "Hey", True, False][4]
#
# IndexError: list index out of range
